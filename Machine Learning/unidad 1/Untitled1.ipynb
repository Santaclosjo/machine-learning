# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from google.colab import drive

# %%
link="/content/0179f453-5a42-446f-8e22-652f227d0022.csv"
df=pd.read_csv(link, sep=",",index_col="_id")
df.head()
dff=df.dropna()
dff.head()
# Out:
#       Total      < 1  1 a 4  5 a 9  ...  20 a 44  45 a 64  65 a 79  80 y Mas
# _id                                 ...
# 2    97.930    1.862  312.0  188.0  ...    7.114   19.462   30.987    37.038
# 3    52.237    1.038  171.0  111.0  ...    5.047   12.255   17.722    15.232
# 4    45.693  824.000  141.0   77.0  ...    2.067    7.207   13.265    21.806
# 5     1.943   27.000   13.0    2.0  ...  359.000  491.000  507.000   531.000
# 6     1.159   17.000    6.0    0.0  ...  287.000  331.000  284.000   228.000
#
# [5 rows x 9 columns]

# %% [markdown]
# En esta tabla podemos ver las  Defunciones, por tumores malignos según localización, por Región en Chile 2000-2010

# %%
DFO=dff[["Total"]]

DFO=DFO.sort_values('Ty6otal')
DFO.describe()
# Out:
#             Total
# count   90.000000
# mean   123.950444
# std    213.501290
# min      1.043000
# 25%      3.535500
# 50%     27.079000
# 75%    115.982500
# max    859.000000

# %% [markdown]
# En esta Funcion podemos apreciar en
#
# *   **count**: la cantidad total de muertes por tumores malignos
#
# *   **Mean:** es la media , la cantidad de muertes media por comuna
# *   **STD:** Es la desviacion standar del total de muertes por tumores
#
# *   **Min:** Es la cantidad minima de muertes por comuna
# *   **25%:** indica el eprcentil 25
# *   **50%:** Indica el percentil 50
# *   **75%:** Indica el percentil 75
# *   **Max:** Es la cantidad maxima registrada en cada comuna de muertes por tumores
# |

# %%
dff["Total"].plot();

# %% [markdown]
# En este grafico podemos ver  que comunas id de comunas hay mas muertes por tumores.

# %%
dr=dff.loc[]

dff.plot(kind = 'bar', 
             stacked = 'True',         # Muestra las barras apiladas
             alpha = 0.4,               # nivel de transparencia
             width = 0.9,               # Grosor 
             figsize=(20,6));

# %%
dfst=dff[["< 1","1 a 4","5 a 9","10 a 19","20 a 44","45 a 64","65 a 79","80 y Mas"]]
dfst.plot(kind = 'bar',                 #dfst=DataFrame Sin Total xd
             stacked = 'True',         # Muestra las barras apiladas
             alpha = 0.4,               # nivel de transparencia
             width = 0.9,               # Grosor 
             figsize=(20,6));

# %%
dff.max
