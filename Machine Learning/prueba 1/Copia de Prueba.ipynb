# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
link="/content/Anexo_Forma_B_demo_round_traces.csv"
DF= pd.read_csv(link,sep=";")

# %%
DF.count
# Out:
# <bound method DataFrame.count of        Unnamed: 0         Map  ... MatchHeadshots  AvgMatchKillDist
# 0             600  de_inferno  ...              0     501379.183091
# 1             601  de_inferno  ...              0     208807.587297
# 2             602  de_inferno  ...              0     381652.027911
# 3             603  de_inferno  ...              0     289754.503091
# 4             604  de_inferno  ...              0     254527.691176
# ...           ...         ...  ...            ...               ...
# 79152      123775   de_mirage  ...              2     768003.878843
# 79153      123776   de_mirage  ...              3     692262.605640
# 79154      123777   de_mirage  ...              3     161310.783653
# 79155      123778   de_mirage  ...              0     984575.199373
# 79156      123779   de_mirage  ...              2     633305.796231
#
# [79157 rows x 37 columns]>

# %% [markdown]
# # *El primer paso es Cargar los Datos a nuestro ambiente y asegurarnos que se cargaron todos*
# # luego mostraremos el DF y sus columnas  para ir explorando datos.

# %%
DF.head(9)
# Out:
#    Unnamed: 0         Map  ... MatchHeadshots  AvgMatchKillDist
# 0         600  de_inferno  ...              0     501379.183091
# 1         601  de_inferno  ...              0     208807.587297
# 2         602  de_inferno  ...              0     381652.027911
# 3         603  de_inferno  ...              0     289754.503091
# 4         604  de_inferno  ...              0     254527.691176
# 5         605  de_inferno  ...              0     437982.273268
# 6         606  de_inferno  ...              0     335133.830648
# 7         607  de_inferno  ...              0     312706.360002
# 8         608  de_inferno  ...              1     365548.186823
#
# [9 rows x 37 columns]

# %%
DF.columns
# Out:
# Index(['Unnamed: 0', 'Map', 'Team', 'InternalTeamId', 'MatchId', 'RoundId',
#        'SteamId', 'RoundWinner', 'MatchWinner', 'Survived', 'AbnormalMatch',
#        'TimeAlive', 'ScaledTimeAlive', 'AvgCentroidDistance',
#        'TravelledDistance', 'AvgRoundVelocity', 'AvgKillDistance',
#        'AvgSiteDistance', 'RLethalGrenadesThrown', 'RNonLethalGrenadesThrown',
#        'PrimaryAssaultRifle', 'PrimarySniperRifle', 'PrimaryHeavy',
#        'PrimarySMG', 'PrimaryPistol', 'FirstKillTime', 'RoundKills',
#        'RoundAssists', 'RoundHeadshots', 'RoundFlankKills',
#        'RoundStartingEquipmentValue', 'TeamStartingEquipmentValue',
#        'MatchKills', 'MatchFlankKills', 'MatchAssists', 'MatchHeadshots',
#        'AvgMatchKillDist'],
#       dtype='object')

# %% [markdown]
# ## Esta tabla muestra los primeros 9 datos de nuestro Data Frame.

# %%
DF.sample(9)
# Out:
#        Unnamed: 0         Map  ... MatchHeadshots  AvgMatchKillDist
# 68420      109783   de_mirage  ...              5      5.122501e+05
# 65547      105010   de_mirage  ...             11      8.720974e+05
# 12315       19126    de_dust2  ...              4      5.869495e+05
# 19304       30345  de_inferno  ...              6      5.514100e+05
# 78123      122446  de_inferno  ...              0      2.938678e+05
# 744          2225   de_mirage  ...              2      4.796667e+05
# 49300       76192    de_dust2  ...              4      6.515016e+05
# 20927       31968  de_inferno  ...              6      2.942540e+05
# 76980      121303    de_dust2  ...              2      1.099995e+06
#
# [9 rows x 37 columns]

# %% [markdown]
# # Otro Tipo de exploracion de Datos es este, que muestra 9 filas aleatorias.
# # A continuacion verificaremos cuantos campos sin completar hay en nuestro DF.

# %%
DF.isnull().sum() ##Este código nos dirá en qué columnas se encuentran nuestros valores NaN:
# Out:
# Unnamed: 0                     0
# Map                            0
# Team                           0
# InternalTeamId                 0
# MatchId                        0
# RoundId                        0
# SteamId                        0
# RoundWinner                    0
# MatchWinner                    0
# Survived                       0
# AbnormalMatch                  0
# TimeAlive                      0
# ScaledTimeAlive                0
# AvgCentroidDistance            0
# TravelledDistance              0
# AvgRoundVelocity               0
# AvgKillDistance                0
# AvgSiteDistance                0
# RLethalGrenadesThrown          0
# RNonLethalGrenadesThrown       0
# PrimaryAssaultRifle            0
# PrimarySniperRifle             0
# PrimaryHeavy                   0
# PrimarySMG                     0
# PrimaryPistol                  0
# FirstKillTime                  0
# RoundKills                     0
# RoundAssists                   0
# ...

# %% [markdown]
# # Acontinuacion mostaremos los tipos de datos clasificados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Claro que podemos obtener un resultado parecido con el siguiente comando:

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79157 entries, 0 to 79156
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   79157 non-null  int64
#  1   Map                          79157 non-null  object
#  2   Team                         79157 non-null  object
#  3   InternalTeamId               79157 non-null  int64
#  4   MatchId                      79157 non-null  int64
#  5   RoundId                      79157 non-null  int64
#  6   SteamId                      79157 non-null  int64
#  7   RoundWinner                  79157 non-null  bool
#  8   MatchWinner                  79157 non-null  bool
#  9   Survived                     79157 non-null  bool
#  10  AbnormalMatch                79157 non-null  bool
#  11  TimeAlive                    79157 non-null  float64
#  12  ScaledTimeAlive              79157 non-null  float64
# ...
