# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# Opcion 1

# %%
link="/content/Anexo Forma B_demo_round_traces.csv"
DF= pd.read_csv(link,sep=";")

# %% [markdown]
# opcion 2

# %%
DF.count
# Out:
# <bound method DataFrame.count of        Unnamed: 0         Map  ... MatchHeadshots  AvgMatchKillDist
# 0             600  de_inferno  ...              0     501379.183091
# 1             601  de_inferno  ...              0     208807.587297
# 2             602  de_inferno  ...              0     381652.027911
# 3             603  de_inferno  ...              0     289754.503091
# 4             604  de_inferno  ...              0     254527.691176
# ...           ...         ...  ...            ...               ...
# 79152      123775   de_mirage  ...              2     768003.878843
# 79153      123776   de_mirage  ...              3     692262.605640
# 79154      123777   de_mirage  ...              3     161310.783653
# 79155      123778   de_mirage  ...              0     984575.199373
# 79156      123779   de_mirage  ...              2     633305.796231
#
# [79157 rows x 37 columns]>

# %% [markdown]
# # Como inicio se deben cargar los datos de nuestro ambiente y luego verificar que todo lo cargado este de forma correcta.
#
# # Luego se exhibiran los **DF** y sus respectivas columnas para la exploración de datos.

# %% [markdown]
# #Está tabla muestra los primeros 9 datos de la respectiva **Data Frame**.#

# %%
DF.head(9)
# Out:
#    Unnamed: 0         Map  ... MatchHeadshots  AvgMatchKillDist
# 0         600  de_inferno  ...              0     501379.183091
# 1         601  de_inferno  ...              0     208807.587297
# 2         602  de_inferno  ...              0     381652.027911
# 3         603  de_inferno  ...              0     289754.503091
# 4         604  de_inferno  ...              0     254527.691176
# 5         605  de_inferno  ...              0     437982.273268
# 6         606  de_inferno  ...              0     335133.830648
# 7         607  de_inferno  ...              0     312706.360002
# 8         608  de_inferno  ...              1     365548.186823
#
# [9 rows x 37 columns]

# %%
DF.columns
## se Verifican las cantidad de columnas
# Out:
# Index(['Unnamed: 0', 'Map', 'Team', 'InternalTeamId', 'MatchId', 'RoundId',
#        'SteamId', 'RoundWinner', 'MatchWinner', 'Survived', 'AbnormalMatch',
#        'TimeAlive', 'ScaledTimeAlive', 'AvgCentroidDistance',
#        'TravelledDistance', 'AvgRoundVelocity', 'AvgKillDistance',
#        'AvgSiteDistance', 'RLethalGrenadesThrown', 'RNonLethalGrenadesThrown',
#        'PrimaryAssaultRifle', 'PrimarySniperRifle', 'PrimaryHeavy',
#        'PrimarySMG', 'PrimaryPistol', 'FirstKillTime', 'RoundKills',
#        'RoundAssists', 'RoundHeadshots', 'RoundFlankKills',
#        'RoundStartingEquipmentValue', 'TeamStartingEquipmentValue',
#        'MatchKills', 'MatchFlankKills', 'MatchAssists', 'MatchHeadshots',
#        'AvgMatchKillDist'],
#       dtype='object')

# %% [markdown]
# # Acá se puede apreciar otro tipo de exploración de datos, el cuál muestra 9 filas de forma aleatoria.
# # También se verificarán los campos que aún permanecen sin completar dentro del **DF**

# %%
DF.sample(9)
# Out:
#        Unnamed: 0         Map  ... MatchHeadshots  AvgMatchKillDist
# 19838       30879    de_dust2  ...            1.0      8.164592e+05
# 55567       83849  de_inferno  ...            5.0      3.611148e+05
# 55041       83053     de_nuke  ...            1.0      1.047899e+06
# 8038        11869  de_inferno  ...            4.0      3.255837e+05
# 66733      107396    de_dust2  ...            2.0      1.547961e+06
# 32967       46519   de_mirage  ...            3.0      5.294666e+05
# 25951       36992     de_nuke  ...            4.0      4.528854e+05
# 64451      103044  de_inferno  ...            4.0      4.578684e+05
# 22342       33383   de_mirage  ...           11.0      9.001700e+05
#
# [9 rows x 37 columns]

# %%
DF.isnull().sum() ##Este código nos dirá en qué columnas se encuentran nuestros valores NaN:
# Out:
# Unnamed: 0                     0
# Map                            0
# Team                           0
# InternalTeamId                 0
# MatchId                        0
# RoundId                        0
# SteamId                        0
# RoundWinner                    0
# MatchWinner                    0
# Survived                       0
# AbnormalMatch                  0
# TimeAlive                      0
# ScaledTimeAlive                0
# AvgCentroidDistance            0
# TravelledDistance              0
# AvgRoundVelocity               0
# AvgKillDistance                0
# AvgSiteDistance                0
# RLethalGrenadesThrown          0
# RNonLethalGrenadesThrown       0
# PrimaryAssaultRifle            0
# PrimarySniperRifle             0
# PrimaryHeavy                   0
# PrimarySMG                     0
# PrimaryPistol                  0
# FirstKillTime                  0
# RoundKills                     0
# RoundAssists                   0
# ...

# %% [markdown]
# **Se analizo que no existen datos NaN**

# %% [markdown]
# # A continuación se podrán verificar los tipos de datos clasificados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Datos que representan la cantidad de kills (**Muertes**) efectuados por el jugador durante la partida o ronda.

# %%
DF['RoundKills'].describe()
# Out:
# count    69585.000000
# mean         0.671553
# std          0.879873
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: RoundKills, dtype: float64

# %% [markdown]
# #Datos que representan la cantidad de asistencias que realizan los jugadores durante las partidas#

# %%
DF['MatchAssists'].describe()
# Out:
# count    79157.000000
# mean         1.874831
# std          1.824027
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max         14.000000
# Name: MatchAssists, dtype: float64

# %% [markdown]
# Con esta informacion podemos analizar que  en promedio ocurren entre 1 o 2 asistencias por partida.

# %% [markdown]
# #Datos que representan la cantidad de Headshosts (**Disparos en la cabeza)** efectuados por el jugador durante la partida o ronda.#

# %%
DF['RoundHeadshots'].describe()
# Out:
# count    79157.000000
# mean         0.301553
# std          0.578843
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          5.000000
# Name: RoundHeadshots, dtype: float64

# %% [markdown]
# #Datos que representan la cantidad de jugadores que ocupa como arma primaria el sniper **(Francotirador)**#

# %%
DF['PrimarySniperRifle'].describe()
# Out:
# count    79157.000000
# mean         0.089840
# std          0.279797
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: PrimarySniperRifle, dtype: float64

# %% [markdown]
# **Indices de resumen basicos**
# # Está tabla contiene indices como:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #En el siguiente gráfico se verán reflejadas las siguientes estadisticas#
# #RoundWinner =

# %%
DFK=DF[["RoundWinner","Map","RoundKills","RoundHeadshots"]]

# %%
grupo=DFK.groupby("Map").sum()
grupo.head()
# Out:
#             RoundWinner  RoundKills  RoundHeadshots
# Map
# de_dust2           9560       12851            5897
# de_inferno        14429       19246            8805
# de_mirage          9504       12836            5448
# de_nuke            6075        8209            3720

# %%
grupo.plot(kind="bar", figsize=(10,10))
plt.title('muertes por mapa')
ax.set_xlabel('Tipo de mapa')  #Nombre del eje x

plt.show();

# %% [markdown]
# # Este Grafico representa la cantidad de partidas ganadas,cantidad de asesinatos y  tiros en la cabeza  clasificados por cada mapa que hay en el juego.
# # En este grafico podemos deducir que existe una relacion entre las variables.
# # Estas estan relacionadas con el tipo de mapa,suguiere  que en el mapa "inferno" ocurren mas tiros en la cabeza que en el resto de los mapas y que en este mapa los jugadores han ganado mas partidas.
